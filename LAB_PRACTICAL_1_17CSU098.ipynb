# %% [markdown]
# #**TEXT AND WEB ANALYTICS**
#
# ##**LAB PRACTICAL 1**
#
# ###**MAHIMA MUNJAL**
#
# ###**17CSU098**

# %% [markdown]
# **Q1. Import the corpus shakespeare and find the frequency of each word in the file dream.xml.**

# %%
import nltk
from nltk.corpus import shakespeare

# %%
nltk.download('shakespeare')
# Out:
# [nltk_data] Downloading package shakespeare to /root/nltk_data...
# [nltk_data]   Package shakespeare is already up-to-date!
# True

# %%
shakespeare.fileids()
# Out:
# ['a_and_c.xml',
#  'dream.xml',
#  'hamlet.xml',
#  'j_caesar.xml',
#  'macbeth.xml',
#  'merchant.xml',
#  'othello.xml',
#  'r_and_j.xml']

# %%
dream= nltk.corpus.shakespeare.words('dream.xml')
dream
# Out:
# ['A',
#  'Midsummer',
#  'Night',
#  "'",
#  's',
#  'Dream',
#  'Dramatis',
#  'Personae',
#  'THESEUS',
#  ',',
#  'Duke',
#  'of',
#  'Athens',
#  '.',
#  'EGEUS',
#  ',',
#  'father',
#  'to',
#  'Hermia',
#  '.',
#  'LYSANDER',
#  'DEMETRIUS',
#  'in',
#  'love',
#  'with',
#  'Hermia',
#  '.',
#  'PHILOSTRATE',
#  ',',
#  'master',
#  'of',
#  'the',
#  'revels',
#  'to',
#  'Theseus',
#  '.',
#  'QUINCE',
#  ',',
#  'a',
#  'carpenter',
#  '.',
#  'SNUG',
#  ',',
#  'a',
#  'joiner',
#  '.',
#  'BOTTOM',
#  ',',
#  'a',
#  'weaver',
#  '.',
#  'FLUTE',
#  ',',
#  'a',
#  'bellows',
#  '-',
#  'mender',
#  '.',
#  'SNOUT',
#  ',',
#  'a',
#  'tinker',
#  '.',
#  'STARVELING',
#  ',',
#  'a',
#  'tailor',
#  '.',
#  'HIPPOLYTA',
#  ',',
#  'queen',
#  'of',
#  'the',
#  'Amazons',
#  ',',
#  'betrothed',
#  'to',
#  'Theseus',
#  '.',
#  'HERMIA',
#  ',',
#  'daughter',
#  'to',
#  'Egeus',
#  ',',
#  'in',
#  'love',
#  'with',
#  'Lysander',
#  '.',
#  'HELENA',
#  ',',
#  'in',
#  'love',
#  'with',
#  'Demetrius',
#  '.',
#  'OBERON',
#  ',',
#  'king',
#  'of',
#  'the',
#  'fairies',
#  '.',
#  'TITANIA',
#  ',',
#  'queen',
#  'of',
#  'the',
#  'fairies',
#  '.',
#  'PUCK',
#  ',',
#  'or',
#  'Robin',
#  'Goodfellow',
#  '.',
#  'PEASEBLOSSOM',
#  'COBWEB',
#  'MOTH',
#  'MUSTARDSEED',
#  'fairies',
#  '.',
#  'Other',
#  'fairies',
#  'attending',
#  'their',
#  'King',
#  'and',
#  'Queen',
#  '.',
#  'Attendants',
#  'on',
#  'Theseus',
#  'and',
#  'Hippolyta',
#  '.',
#  'SCENE',
#  'Athens',
#  ',',
#  'and',
#  'a',
#  'wood',
#  'near',
#  'it',
#  '.',
#  'A',
#  'MIDSUMMER',
#  'NIGHT',
#  "'",
#  'S',
#  'DREAM',
#  'ACT',
#  'I',
#  'SCENE',
#  'I',
#  '.',
#  'Athens',
#  '.',
#  'The',
#  'palace',
#  'of',
#  'THESEUS',
#  '.',
#  'Enter',
#  'THESEUS',
#  ',',
#  'HIPPOLYTA',
#  ',',
#  'PHILOSTRATE',
#  ',',
#  'and',
#  'Attendants',
#  'THESEUS',
#  'Now',
#  ',',
#  'fair',
#  'Hippolyta',
#  ',',
#  'our',
#  'nuptial',
#  'hour',
#  'Draws',
#  'on',
#  'apace',
#  ';',
#  'four',
#  'happy',
#  'days',
#  'bring',
#  'in',
#  'Another',
#  'moon',
#  ':',
#  'but',
#  ',',
#  'O',
#  ',',
#  'methinks',
#  ',',
#  'how',
#  'slow',
#  'This',
#  'old',
#  'moon',
#  'wanes',
#  '!',
#  'she',
#  'lingers',
#  'my',
#  'desires',
#  ',',
#  'Like',
#  'to',
#  'a',
#  'step',
#  '-',
#  'dame',
#  'or',
#  'a',
#  'dowager',
#  'Long',
#  'withering',
#  'out',
#  'a',
#  'young',
#  'man',
#  'revenue',
#  '.',
#  'HIPPOLYTA',
#  'Four',
#  'days',
#  'will',
#  'quickly',
#  'steep',
#  'themselves',
#  'in',
#  'night',
#  ';',
#  'Four',
#  'nights',
#  'will',
#  'quickly',
#  'dream',
#  'away',
#  'the',
#  'time',
#  ';',
#  'And',
#  'then',
#  'the',
#  'moon',
#  ',',
#  'like',
#  'to',
#  'a',
#  'silver',
#  'bow',
#  'New',
#  '-',
#  'bent',
#  'in',
#  'heaven',
#  ',',
#  'shall',
#  'behold',
#  'the',
#  'night',
#  'Of',
#  'our',
#  'solemnities',
#  '.',
#  'THESEUS',
#  'Go',
#  ',',
#  'Philostrate',
#  ',',
#  'Stir',
#  'up',
#  'the',
#  'Athenian',
#  'youth',
#  'to',
#  'merriments',
#  ';',
#  'Awake',
#  'the',
#  'pert',
#  'and',
#  'nimble',
#  'spirit',
#  'of',
#  'mirth',
#  ';',
#  'Turn',
#  'melancholy',
#  'forth',
#  'to',
#  'funerals',
#  ';',
#  'The',
#  'pale',
#  'companion',
#  'is',
#  'not',
#  'for',
#  'our',
#  'pomp',
#  '.',
#  'Exit',
#  'PHILOSTRATE',
#  'Hippolyta',
#  ',',
#  'I',
#  'woo',
#  "'",
#  'd',
#  'thee',
#  'with',
#  'my',
#  'sword',
#  ',',
#  'And',
#  'won',
#  'thy',
#  'love',
#  ',',
#  'doing',
#  'thee',
#  'injuries',
#  ';',
#  'But',
#  'I',
#  'will',
#  'wed',
#  'thee',
#  'in',
#  'another',
#  'key',
#  ',',
#  'With',
#  'pomp',
#  ',',
#  'with',
#  'triumph',
#  'and',
#  'with',
#  'revelling',
#  '.',
#  'Enter',
#  'EGEUS',
#  ',',
#  'HERMIA',
#  ',',
#  'LYSANDER',
#  ',',
#  'and',
#  'DEMETRIUS',
#  'EGEUS',
#  'Happy',
#  'be',
#  'Theseus',
#  ',',
#  'our',
#  'renowned',
#  'duke',
#  '!',
#  'THESEUS',
#  'Thanks',
#  ',',
#  'good',
#  'Egeus',
#  ':',
#  'what',
#  "'",
#  's',
#  'the',
#  'news',
#  'with',
#  'thee',
#  '?',
#  'EGEUS',
#  'Full',
#  'of',
#  'vexation',
#  'come',
#  'I',
#  ',',
#  'with',
#  'complaint',
#  'Against',
#  'my',
#  'child',
#  ',',
#  'my',
#  'daughter',
#  'Hermia',
#  '.',
#  'Stand',
#  'forth',
#  ',',
#  'Demetrius',
#  '.',
#  'My',
#  'noble',
#  'lord',
#  ',',
#  'This',
#  'man',
#  'hath',
#  'my',
#  'consent',
#  'to',
#  'marry',
#  'her',
#  '.',
#  'Stand',
#  'forth',
#  ',',
#  'Lysander',
#  ':',
#  'and',
#  'my',
#  'gracious',
#  'duke',
#  ',',
#  'This',
#  'man',
#  'hath',
#  'bewitch',
#  "'",
#  'd',
#  'the',
#  'bosom',
#  'of',
#  'my',
#  'child',
#  ';',
#  'Thou',
#  ',',
#  'thou',
#  ',',
#  'Lysander',
#  ',',
#  'thou',
#  'hast',
#  'given',
#  'her',
#  'rhymes',
#  ',',
#  'And',
#  'interchanged',
#  'love',
#  '-',
#  'tokens',
#  'with',
#  'my',
#  'child',
#  ':',
#  'Thou',
#  'hast',
#  'by',
#  'moonlight',
#  'at',
#  'her',
#  'window',
#  'sung',
#  ',',
#  'With',
#  'feigning',
#  'voice',
#  'verses',
#  'of',
#  'feigning',
#  'love',
#  ',',
#  'And',
#  'stolen',
#  'the',
#  'impression',
#  'of',
#  'her',
#  'fantasy',
#  'With',
#  'bracelets',
#  'of',
#  'thy',
#  'hair',
#  ',',
#  'rings',
#  ',',
#  'gawds',
#  ',',
#  'conceits',
#  ',',
#  'Knacks',
#  ',',
#  'trifles',
#  ',',
#  'nosegays',
#  ',',
#  'sweetmeats',
#  ',',
#  'messengers',
#  'Of',
#  'strong',
#  'prevailment',
#  'in',
#  'unharden',
#  "'",
#  'd',
#  'youth',
#  ':',
#  'With',
#  'cunning',
#  'hast',
#  'thou',
#  'filch',
#  "'",
#  'd',
#  'my',
#  'daughter',
#  "'",
#  's',
#  'heart',
#  ',',
#  'Turn',
#  "'",
#  'd',
#  'her',
#  'obedience',
#  ',',
#  'which',
#  'is',
#  'due',
#  'to',
#  'me',
#  ',',
#  'To',
#  'stubborn',
#  'harshness',
#  ':',
#  'and',
#  ',',
#  'my',
#  'gracious',
#  'duke',
#  ',',
#  'Be',
#  'it',
#  'so',
#  'she',
#  ';',
#  'will',
#  'not',
#  'here',
#  'before',
#  'your',
#  'grace',
#  'Consent',
#  'to',
#  'marry',
#  'with',
#  'Demetrius',
#  ',',
#  'I',
#  'beg',
#  'the',
#  'ancient',
#  'privilege',
#  'of',
#  'Athens',
#  ',',
#  'As',
#  'she',
#  'is',
#  'mine',
#  ',',
#  'I',
#  'may',
#  'dispose',
#  'of',
#  'her',
#  ':',
#  'Which',
#  'shall',
#  'be',
#  'either',
#  'to',
#  'this',
#  'gentleman',
#  'Or',
#  'to',
#  'her',
#  'death',
#  ',',
#  'according',
#  'to',
#  'our',
#  'law',
#  'Immediately',
#  'provided',
#  'in',
#  'that',
#  'case',
#  '.',
#  'THESEUS',
#  'What',
#  'say',
#  'you',
#  ',',
#  'Hermia',
#  '?',
#  'be',
#  'advised',
#  'fair',
#  'maid',
#  ':',
#  'To',
#  'you',
#  'your',
#  'father',
#  'should',
#  'be',
#  'as',
#  'a',
#  'god',
#  ';',
#  'One',
#  'that',
#  'composed',
#  'your',
#  'beauties',
#  ',',
#  'yea',
#  ',',
#  'and',
#  'one',
#  'To',
#  'whom',
#  'you',
#  'are',
#  'but',
#  'as',
#  'a',
#  'form',
#  'in',
#  'wax',
#  'By',
#  'him',
#  'imprinted',
#  'and',
#  'within',
#  'his',
#  'power',
#  'To',
#  'leave',
#  'the',
#  'figure',
#  'or',
#  'disfigure',
#  'it',
#  '.',
#  'Demetrius',
#  'is',
#  'a',
#  'worthy',
#  'gentleman',
#  '.',
#  'HERMIA',
#  'So',
#  'is',
#  'Lysander',
#  '.',
#  'THESEUS',
#  'In',
#  'himself',
#  'he',
#  'is',
#  ';',
#  'But',
#  'in',
#  'this',
#  'kind',
#  ',',
#  'wanting',
#  'your',
#  'father',
#  "'",
#  's',
#  'voice',
#  ',',
#  'The',
#  'other',
#  'must',
#  'be',
#  'held',
#  'the',
#  'worthier',
#  '.',
#  'HERMIA',
#  'I',
#  'would',
#  'my',
#  'father',
#  'look',
#  "'",
#  'd',
#  'but',
#  'with',
#  'my',
#  'eyes',
#  '.',
#  'THESEUS',
#  'Rather',
#  'your',
#  'eyes',
#  'must',
#  'with',
#  'his',
#  'judgment',
#  'look',
#  '.',
#  'HERMIA',
#  'I',
#  'do',
#  'entreat',
#  'your',
#  'grace',
#  'to',
#  'pardon',
#  'me',
#  '.',
#  'I',
#  'know',
#  'not',
#  'by',
#  'what',
#  'power',
#  'I',
#  'am',
#  'made',
#  'bold',
#  ',',
#  'Nor',
#  'how',
#  'it',
#  'may',
#  'concern',
#  'my',
#  'modesty',
#  ',',
#  'In',
#  'such',
#  'a',
#  'presence',
#  'here',
#  'to',
#  'plead',
#  'my',
#  'thoughts',
#  ';',
#  'But',
#  'I',
#  'beseech',
#  'your',
#  'grace',
#  'that',
#  'I',
#  'may',
#  'know',
#  'The',
#  'worst',
#  'that',
#  'may',
#  'befall',
#  'me',
#  'in',
#  'this',
#  'case',
#  ',',
#  'If',
#  'I',
#  'refuse',
#  'to',
#  'wed',
#  'Demetrius',
#  '.',
#  'THESEUS',
#  'Either',
#  'to',
#  'die',
#  'the',
#  'death',
#  'or',
#  'to',
#  'abjure',
#  'For',
#  'ever',
#  'the',
#  'society',
#  'of',
#  'men',
#  '.',
#  'Therefore',
#  ',',
#  'fair',
#  'Hermia',
#  ',',
#  'question',
#  'your',
#  'desires',
#  ';',
#  'Know',
#  'of',
#  'your',
#  'youth',
#  ',',
#  'examine',
#  'well',
#  'your',
#  'blood',
#  ',',
#  'Whether',
#  ',',
#  'if',
#  'you',
#  'yield',
#  'not',
#  'to',
#  'your',
#  'father',
#  "'",
#  's',
#  'choice',
#  ',',
#  'You',
#  'can',
#  'endure',
#  'the',
#  'livery',
#  'of',
#  'a',
#  'nun',
#  ',',
#  'For',
#  'aye',
#  'to',
#  'be',
#  'in',
#  'shady',
#  'cloister',
#  'mew',
#  "'",
#  'd',
#  ',',
#  'To',
#  'live',
#  'a',
#  'barren',
#  'sister',
#  'all',
#  'your',
#  'life',
#  ',',
#  'Chanting',
#  'faint',
#  'hymns',
#  'to',
#  'the',
#  'cold',
#  'fruitless',
#  'moon',
#  '.',
#  'Thrice',
#  '-',
#  'blessed',
#  'they',
#  'that',
#  'master',
#  'so',
#  'their',
#  'blood',
#  ',',
#  'To',
#  'undergo',
#  'such',
#  'maiden',
#  'pilgrimage',
#  ';',
#  'But',
#  'earthlier',
#  'happy',
#  'is',
#  'the',
#  'rose',
#  'distill',
#  "'",
#  'd',
#  ',',
#  'Than',
#  'that',
#  'which',
#  'withering',
#  'on',
#  'the',
#  'virgin',
#  'thorn',
#  'Grows',
#  ',',
#  'lives',
#  'and',
#  'dies',
#  'in',
#  'single',
#  'blessedness',
#  '.',
#  'HERMIA',
#  'So',
#  'will',
#  'I',
#  'grow',
#  ',',
#  'so',
#  'live',
#  ',',
#  'so',
#  'die',
#  ',',
#  'my',
#  'lord',
#  ',',
#  'Ere',
#  'I',
#  'will',
#  'my',
#  'virgin',
#  'patent',
#  'up',
#  'Unto',
#  'his',
#  'lordship',
#  ',',
#  'whose',
#  'unwished',
#  'yoke',
#  'My',
#  'soul',
#  'consents',
#  'not',
#  'to',
#  'give',
#  'sovereignty',
#  '.',
#  'THESEUS',
#  'Take',
#  'time',
#  'to',
#  'pause',
#  ';',
#  'and',
#  ',',
#  'by',
#  'the',
#  'nest',
#  'new',
#  'moon',
#  '--',
#  'The',
#  'sealing',
#  '-',
#  'day',
#  'betwixt',
#  'my',
#  'love',
#  'and',
#  'me',
#  ',',
#  'For',
#  'everlasting',
#  'bond',
#  'of',
#  'fellowship',
#  '--',
#  'Upon',
#  'that',
#  'day',
#  'either',
#  'prepare',
#  'to',
#  'die',
#  'For',
#  'disobedience',
#  'to',
#  'your',
#  'father',
#  "'",
#  's',
#  'will',
#  ',',
#  ...]

# %%
len(dream)
# Out:
# 21538

# %%
#cleaning data of punctuations
import string
l=string.punctuation.split()
no_punct_dream=[words for words in dream if words not in string.punctuation]
no_punct_dream
# Out:
# ['A',
#  'Midsummer',
#  'Night',
#  's',
#  'Dream',
#  'Dramatis',
#  'Personae',
#  'THESEUS',
#  'Duke',
#  'of',
#  'Athens',
#  'EGEUS',
#  'father',
#  'to',
#  'Hermia',
#  'LYSANDER',
#  'DEMETRIUS',
#  'in',
#  'love',
#  'with',
#  'Hermia',
#  'PHILOSTRATE',
#  'master',
#  'of',
#  'the',
#  'revels',
#  'to',
#  'Theseus',
#  'QUINCE',
#  'a',
#  'carpenter',
#  'SNUG',
#  'a',
#  'joiner',
#  'BOTTOM',
#  'a',
#  'weaver',
#  'FLUTE',
#  'a',
#  'bellows',
#  'mender',
#  'SNOUT',
#  'a',
#  'tinker',
#  'STARVELING',
#  'a',
#  'tailor',
#  'HIPPOLYTA',
#  'queen',
#  'of',
#  'the',
#  'Amazons',
#  'betrothed',
#  'to',
#  'Theseus',
#  'HERMIA',
#  'daughter',
#  'to',
#  'Egeus',
#  'in',
#  'love',
#  'with',
#  'Lysander',
#  'HELENA',
#  'in',
#  'love',
#  'with',
#  'Demetrius',
#  'OBERON',
#  'king',
#  'of',
#  'the',
#  'fairies',
#  'TITANIA',
#  'queen',
#  'of',
#  'the',
#  'fairies',
#  'PUCK',
#  'or',
#  'Robin',
#  'Goodfellow',
#  'PEASEBLOSSOM',
#  'COBWEB',
#  'MOTH',
#  'MUSTARDSEED',
#  'fairies',
#  'Other',
#  'fairies',
#  'attending',
#  'their',
#  'King',
#  'and',
#  'Queen',
#  'Attendants',
#  'on',
#  'Theseus',
#  'and',
#  'Hippolyta',
#  'SCENE',
#  'Athens',
#  'and',
#  'a',
#  'wood',
#  'near',
#  'it',
#  'A',
#  'MIDSUMMER',
#  'NIGHT',
#  'S',
#  'DREAM',
#  'ACT',
#  'I',
#  'SCENE',
#  'I',
#  'Athens',
#  'The',
#  'palace',
#  'of',
#  'THESEUS',
#  'Enter',
#  'THESEUS',
#  'HIPPOLYTA',
#  'PHILOSTRATE',
#  'and',
#  'Attendants',
#  'THESEUS',
#  'Now',
#  'fair',
#  'Hippolyta',
#  'our',
#  'nuptial',
#  'hour',
#  'Draws',
#  'on',
#  'apace',
#  'four',
#  'happy',
#  'days',
#  'bring',
#  'in',
#  'Another',
#  'moon',
#  'but',
#  'O',
#  'methinks',
#  'how',
#  'slow',
#  'This',
#  'old',
#  'moon',
#  'wanes',
#  'she',
#  'lingers',
#  'my',
#  'desires',
#  'Like',
#  'to',
#  'a',
#  'step',
#  'dame',
#  'or',
#  'a',
#  'dowager',
#  'Long',
#  'withering',
#  'out',
#  'a',
#  'young',
#  'man',
#  'revenue',
#  'HIPPOLYTA',
#  'Four',
#  'days',
#  'will',
#  'quickly',
#  'steep',
#  'themselves',
#  'in',
#  'night',
#  'Four',
#  'nights',
#  'will',
#  'quickly',
#  'dream',
#  'away',
#  'the',
#  'time',
#  'And',
#  'then',
#  'the',
#  'moon',
#  'like',
#  'to',
#  'a',
#  'silver',
#  'bow',
#  'New',
#  'bent',
#  'in',
#  'heaven',
#  'shall',
#  'behold',
#  'the',
#  'night',
#  'Of',
#  'our',
#  'solemnities',
#  'THESEUS',
#  'Go',
#  'Philostrate',
#  'Stir',
#  'up',
#  'the',
#  'Athenian',
#  'youth',
#  'to',
#  'merriments',
#  'Awake',
#  'the',
#  'pert',
#  'and',
#  'nimble',
#  'spirit',
#  'of',
#  'mirth',
#  'Turn',
#  'melancholy',
#  'forth',
#  'to',
#  'funerals',
#  'The',
#  'pale',
#  'companion',
#  'is',
#  'not',
#  'for',
#  'our',
#  'pomp',
#  'Exit',
#  'PHILOSTRATE',
#  'Hippolyta',
#  'I',
#  'woo',
#  'd',
#  'thee',
#  'with',
#  'my',
#  'sword',
#  'And',
#  'won',
#  'thy',
#  'love',
#  'doing',
#  'thee',
#  'injuries',
#  'But',
#  'I',
#  'will',
#  'wed',
#  'thee',
#  'in',
#  'another',
#  'key',
#  'With',
#  'pomp',
#  'with',
#  'triumph',
#  'and',
#  'with',
#  'revelling',
#  'Enter',
#  'EGEUS',
#  'HERMIA',
#  'LYSANDER',
#  'and',
#  'DEMETRIUS',
#  'EGEUS',
#  'Happy',
#  'be',
#  'Theseus',
#  'our',
#  'renowned',
#  'duke',
#  'THESEUS',
#  'Thanks',
#  'good',
#  'Egeus',
#  'what',
#  's',
#  'the',
#  'news',
#  'with',
#  'thee',
#  'EGEUS',
#  'Full',
#  'of',
#  'vexation',
#  'come',
#  'I',
#  'with',
#  'complaint',
#  'Against',
#  'my',
#  'child',
#  'my',
#  'daughter',
#  'Hermia',
#  'Stand',
#  'forth',
#  'Demetrius',
#  'My',
#  'noble',
#  'lord',
#  'This',
#  'man',
#  'hath',
#  'my',
#  'consent',
#  'to',
#  'marry',
#  'her',
#  'Stand',
#  'forth',
#  'Lysander',
#  'and',
#  'my',
#  'gracious',
#  'duke',
#  'This',
#  'man',
#  'hath',
#  'bewitch',
#  'd',
#  'the',
#  'bosom',
#  'of',
#  'my',
#  'child',
#  'Thou',
#  'thou',
#  'Lysander',
#  'thou',
#  'hast',
#  'given',
#  'her',
#  'rhymes',
#  'And',
#  'interchanged',
#  'love',
#  'tokens',
#  'with',
#  'my',
#  'child',
#  'Thou',
#  'hast',
#  'by',
#  'moonlight',
#  'at',
#  'her',
#  'window',
#  'sung',
#  'With',
#  'feigning',
#  'voice',
#  'verses',
#  'of',
#  'feigning',
#  'love',
#  'And',
#  'stolen',
#  'the',
#  'impression',
#  'of',
#  'her',
#  'fantasy',
#  'With',
#  'bracelets',
#  'of',
#  'thy',
#  'hair',
#  'rings',
#  'gawds',
#  'conceits',
#  'Knacks',
#  'trifles',
#  'nosegays',
#  'sweetmeats',
#  'messengers',
#  'Of',
#  'strong',
#  'prevailment',
#  'in',
#  'unharden',
#  'd',
#  'youth',
#  'With',
#  'cunning',
#  'hast',
#  'thou',
#  'filch',
#  'd',
#  'my',
#  'daughter',
#  's',
#  'heart',
#  'Turn',
#  'd',
#  'her',
#  'obedience',
#  'which',
#  'is',
#  'due',
#  'to',
#  'me',
#  'To',
#  'stubborn',
#  'harshness',
#  'and',
#  'my',
#  'gracious',
#  'duke',
#  'Be',
#  'it',
#  'so',
#  'she',
#  'will',
#  'not',
#  'here',
#  'before',
#  'your',
#  'grace',
#  'Consent',
#  'to',
#  'marry',
#  'with',
#  'Demetrius',
#  'I',
#  'beg',
#  'the',
#  'ancient',
#  'privilege',
#  'of',
#  'Athens',
#  'As',
#  'she',
#  'is',
#  'mine',
#  'I',
#  'may',
#  'dispose',
#  'of',
#  'her',
#  'Which',
#  'shall',
#  'be',
#  'either',
#  'to',
#  'this',
#  'gentleman',
#  'Or',
#  'to',
#  'her',
#  'death',
#  'according',
#  'to',
#  'our',
#  'law',
#  'Immediately',
#  'provided',
#  'in',
#  'that',
#  'case',
#  'THESEUS',
#  'What',
#  'say',
#  'you',
#  'Hermia',
#  'be',
#  'advised',
#  'fair',
#  'maid',
#  'To',
#  'you',
#  'your',
#  'father',
#  'should',
#  'be',
#  'as',
#  'a',
#  'god',
#  'One',
#  'that',
#  'composed',
#  'your',
#  'beauties',
#  'yea',
#  'and',
#  'one',
#  'To',
#  'whom',
#  'you',
#  'are',
#  'but',
#  'as',
#  'a',
#  'form',
#  'in',
#  'wax',
#  'By',
#  'him',
#  'imprinted',
#  'and',
#  'within',
#  'his',
#  'power',
#  'To',
#  'leave',
#  'the',
#  'figure',
#  'or',
#  'disfigure',
#  'it',
#  'Demetrius',
#  'is',
#  'a',
#  'worthy',
#  'gentleman',
#  'HERMIA',
#  'So',
#  'is',
#  'Lysander',
#  'THESEUS',
#  'In',
#  'himself',
#  'he',
#  'is',
#  'But',
#  'in',
#  'this',
#  'kind',
#  'wanting',
#  'your',
#  'father',
#  's',
#  'voice',
#  'The',
#  'other',
#  'must',
#  'be',
#  'held',
#  'the',
#  'worthier',
#  'HERMIA',
#  'I',
#  'would',
#  'my',
#  'father',
#  'look',
#  'd',
#  'but',
#  'with',
#  'my',
#  'eyes',
#  'THESEUS',
#  'Rather',
#  'your',
#  'eyes',
#  'must',
#  'with',
#  'his',
#  'judgment',
#  'look',
#  'HERMIA',
#  'I',
#  'do',
#  'entreat',
#  'your',
#  'grace',
#  'to',
#  'pardon',
#  'me',
#  'I',
#  'know',
#  'not',
#  'by',
#  'what',
#  'power',
#  'I',
#  'am',
#  'made',
#  'bold',
#  'Nor',
#  'how',
#  'it',
#  'may',
#  'concern',
#  'my',
#  'modesty',
#  'In',
#  'such',
#  'a',
#  'presence',
#  'here',
#  'to',
#  'plead',
#  'my',
#  'thoughts',
#  'But',
#  'I',
#  'beseech',
#  'your',
#  'grace',
#  'that',
#  'I',
#  'may',
#  'know',
#  'The',
#  'worst',
#  'that',
#  'may',
#  'befall',
#  'me',
#  'in',
#  'this',
#  'case',
#  'If',
#  'I',
#  'refuse',
#  'to',
#  'wed',
#  'Demetrius',
#  'THESEUS',
#  'Either',
#  'to',
#  'die',
#  'the',
#  'death',
#  'or',
#  'to',
#  'abjure',
#  'For',
#  'ever',
#  'the',
#  'society',
#  'of',
#  'men',
#  'Therefore',
#  'fair',
#  'Hermia',
#  'question',
#  'your',
#  'desires',
#  'Know',
#  'of',
#  'your',
#  'youth',
#  'examine',
#  'well',
#  'your',
#  'blood',
#  'Whether',
#  'if',
#  'you',
#  'yield',
#  'not',
#  'to',
#  'your',
#  'father',
#  's',
#  'choice',
#  'You',
#  'can',
#  'endure',
#  'the',
#  'livery',
#  'of',
#  'a',
#  'nun',
#  'For',
#  'aye',
#  'to',
#  'be',
#  'in',
#  'shady',
#  'cloister',
#  'mew',
#  'd',
#  'To',
#  'live',
#  'a',
#  'barren',
#  'sister',
#  'all',
#  'your',
#  'life',
#  'Chanting',
#  'faint',
#  'hymns',
#  'to',
#  'the',
#  'cold',
#  'fruitless',
#  'moon',
#  'Thrice',
#  'blessed',
#  'they',
#  'that',
#  'master',
#  'so',
#  'their',
#  'blood',
#  'To',
#  'undergo',
#  'such',
#  'maiden',
#  'pilgrimage',
#  'But',
#  'earthlier',
#  'happy',
#  'is',
#  'the',
#  'rose',
#  'distill',
#  'd',
#  'Than',
#  'that',
#  'which',
#  'withering',
#  'on',
#  'the',
#  'virgin',
#  'thorn',
#  'Grows',
#  'lives',
#  'and',
#  'dies',
#  'in',
#  'single',
#  'blessedness',
#  'HERMIA',
#  'So',
#  'will',
#  'I',
#  'grow',
#  'so',
#  'live',
#  'so',
#  'die',
#  'my',
#  'lord',
#  'Ere',
#  'I',
#  'will',
#  'my',
#  'virgin',
#  'patent',
#  'up',
#  'Unto',
#  'his',
#  'lordship',
#  'whose',
#  'unwished',
#  'yoke',
#  'My',
#  'soul',
#  'consents',
#  'not',
#  'to',
#  'give',
#  'sovereignty',
#  'THESEUS',
#  'Take',
#  'time',
#  'to',
#  'pause',
#  'and',
#  'by',
#  'the',
#  'nest',
#  'new',
#  'moon',
#  '--',
#  'The',
#  'sealing',
#  'day',
#  'betwixt',
#  'my',
#  'love',
#  'and',
#  'me',
#  'For',
#  'everlasting',
#  'bond',
#  'of',
#  'fellowship',
#  '--',
#  'Upon',
#  'that',
#  'day',
#  'either',
#  'prepare',
#  'to',
#  'die',
#  'For',
#  'disobedience',
#  'to',
#  'your',
#  'father',
#  's',
#  'will',
#  'Or',
#  'else',
#  'to',
#  'wed',
#  'Demetrius',
#  'as',
#  'he',
#  'would',
#  'Or',
#  'on',
#  'Diana',
#  's',
#  'altar',
#  'to',
#  'protest',
#  'For',
#  'aye',
#  'austerity',
#  'and',
#  'single',
#  'life',
#  'DEMETRIUS',
#  'Relent',
#  'sweet',
#  'Hermia',
#  'and',
#  'Lysander',
#  'yield',
#  'Thy',
#  'crazed',
#  'title',
#  'to',
#  'my',
#  'certain',
#  'right',
#  'LYSANDER',
#  'You',
#  'have',
#  'her',
#  'father',
#  's',
#  'love',
#  'Demetrius',
#  'Let',
#  'me',
#  'have',
#  'Hermia',
#  's',
#  'do',
#  'you',
#  'marry',
#  'him',
#  'EGEUS',
#  'Scornful',
#  'Lysander',
#  'true',
#  'he',
#  'hath',
#  'my',
#  'love',
#  'And',
#  'what',
#  'is',
#  'mine',
#  'my',
#  'love',
#  'shall',
#  'render',
#  'him',
#  'And',
#  'she',
#  'is',
#  'mine',
#  'and',
#  'all',
#  'my',
#  'right',
#  'of',
#  'her',
#  'I',
#  'do',
#  'estate',
#  'unto',
#  'Demetrius',
#  'LYSANDER',
#  'I',
#  'am',
#  'my',
#  'lord',
#  'as',
#  'well',
#  'derived',
#  'as',
#  'he',
#  'As',
#  'well',
#  'possess',
#  'd',
#  'my',
#  'love',
#  'is',
#  'more',
#  'than',
#  'his',
#  'My',
#  'fortunes',
#  'every',
#  'way',
#  'as',
#  'fairly',
#  'rank',
#  'd',
#  'If',
#  'not',
#  'with',
#  'vantage',
#  'as',
#  'Demetrius',
#  "';",
#  'And',
#  'which',
#  'is',
#  'more',
#  'than',
#  'all',
#  'these',
#  'boasts',
#  'can',
#  'be',
#  'I',
#  'am',
#  'beloved',
#  'of',
#  'beauteous',
#  'Hermia',
#  'Why',
#  'should',
#  'not',
#  'I',
#  'then',
#  'prosecute',
#  'my',
#  'right',
#  'Demetrius',
#  'I',
#  'll',
#  'avouch',
#  'it',
#  'to',
#  'his',
#  'head',
#  'Made',
#  'love',
#  'to',
#  'Nedar',
#  's',
#  'daughter',
#  'Helena',
#  'And',
#  'won',
#  'her',
#  'soul',
#  'and',
#  'she',
#  'sweet',
#  'lady',
#  'dotes',
#  'Devoutly',
#  'dotes',
#  'dotes',
#  'in',
#  'idolatry',
#  'Upon',
#  'this',
#  'spotted',
#  'and',
#  'inconstant',
#  'man',
#  'THESEUS',
#  'I',
#  'must',
#  'confess',
#  'that',
#  'I',
#  'have',
#  'heard',
#  'so',
#  'much',
#  'And',
#  ...]

# %%
#Finding frequency
fdist=nltk.FreqDist(w.lower() for w in no_punct_dream)
fdist
# Out:
# FreqDist({'a': 273,
#           'midsummer': 2,
#           'night': 52,
#           's': 133,
#           'dream': 16,
#           'dramatis': 1,
#           'personae': 1,
#           'theseus': 67,
#           'duke': 14,
#           'of': 272,
#           'athens': 27,
#           'egeus': 17,
#           'father': 14,
#           'to': 340,
#           'hermia': 103,
#           'lysander': 103,
#           'demetrius': 101,
#           'in': 243,
#           'love': 117,
#           'with': 177,
#           'philostrate': 14,
#           'master': 8,
#           'the': 563,
#           'revels': 5,
#           'quince': 55,
#           'carpenter': 1,
#           'snug': 10,
#           'joiner': 4,
#           'bottom': 69,
#           'weaver': 3,
#           'flute': 19,
#           'bellows': 3,
#           'mender': 3,
#           'snout': 17,
#           'tinker': 3,
#           'starveling': 12,
#           'tailor': 3,
#           'hippolyta': 26,
#           'queen': 15,
#           'amazons': 1,
#           'betrothed': 1,
#           'daughter': 5,
#           'helena': 68,
#           'oberon': 44,
#           'king': 6,
#           'fairies': 13,
#           'titania': 42,
#           'puck': 49,
#           'or': 63,
#           'robin': 7,
#           'goodfellow': 2,
#           'peaseblossom': 12,
#           'cobweb': 13,
#           'moth': 6,
#           'mustardseed': 14,
#           'other': 12,
#           'attending': 2,
#           'their': 52,
#           'and': 574,
#           'attendants': 3,
#           'on': 71,
#           'scene': 12,
#           'wood': 24,
#           'near': 13,
#           'it': 134,
#           'act': 5,
#           'i': 470,
#           'palace': 5,
#           'enter': 54,
#           'now': 66,
#           'fair': 33,
#           'our': 59,
#           'nuptial': 5,
#           'hour': 6,
#           'draws': 3,
#           'apace': 1,
#           'four': 4,
#           'happy': 7,
#           'days': 5,
#           'bring': 8,
#           'another': 11,
#           'moon': 30,
#           'but': 121,
#           'o': 72,
#           'methinks': 9,
#           'how': 36,
#           'slow': 3,
#           'this': 148,
#           'old': 6,
#           'wanes': 1,
#           'she': 63,
#           'lingers': 1,
#           'my': 199,
#           'desires': 3,
#           'like': 27,
#           'step': 1,
#           'dame': 2,
#           'dowager': 2,
#           'long': 12,
#           'withering': 2,
#           'out': 28,
#           'young': 7,
#           'man': 50,
#           'revenue': 2,
#           'will': 116,
#           'quickly': 2,
#           'steep': 1,
#           'themselves': 5,
#           'nights': 1,
#           'away': 23,
#           'time': 11,
#           'then': 47,
#           'silver': 2,
#           'bow': 5,
#           'new': 7,
#           'bent': 2,
#           'heaven': 6,
#           'shall': 72,
#           'behold': 3,
#           'solemnities': 1,
#           'go': 36,
#           'stir': 4,
#           'up': 28,
#           'athenian': 16,
#           'youth': 7,
#           'merriments': 1,
#           'awake': 7,
#           'pert': 1,
#           'nimble': 1,
#           'spirit': 6,
#           'mirth': 5,
#           'turn': 10,
#           'melancholy': 1,
#           'forth': 9,
#           'funerals': 1,
#           'pale': 7,
#           'companion': 1,
#           'is': 194,
#           'not': 170,
#           'for': 143,
#           'pomp': 2,
#           'exit': 32,
#           'woo': 6,
#           'd': 92,
#           'thee': 64,
#           'sword': 6,
#           'won': 2,
#           'thy': 63,
#           'doing': 1,
#           'injuries': 1,
#           'wed': 3,
#           'key': 2,
#           'triumph': 1,
#           'revelling': 1,
#           'be': 105,
#           'renowned': 1,
#           'thanks': 4,
#           'good': 41,
#           'what': 74,
#           'news': 2,
#           'full': 8,
#           'vexation': 2,
#           'come': 59,
#           'complaint': 1,
#           'against': 6,
#           'child': 10,
#           'stand': 11,
#           'noble': 6,
#           'lord': 29,
#           'hath': 36,
#           'consent': 5,
#           'marry': 7,
#           'her': 99,
#           'gracious': 4,
#           'bewitch': 1,
#           'bosom': 2,
#           'thou': 116,
#           'hast': 16,
#           'given': 3,
#           'rhymes': 1,
#           'interchanged': 1,
#           'tokens': 1,
#           'by': 70,
#           'moonlight': 6,
#           'at': 39,
#           'window': 2,
#           'sung': 1,
#           'feigning': 2,
#           'voice': 10,
#           'verses': 1,
#           'stolen': 8,
#           'impression': 1,
#           'fantasy': 1,
#           'bracelets': 1,
#           'hair': 6,
#           'rings': 1,
#           'gawds': 1,
#           'conceits': 1,
#           'knacks': 1,
#           'trifles': 2,
#           'nosegays': 1,
#           'sweetmeats': 1,
#           'messengers': 1,
#           'strong': 3,
#           'prevailment': 1,
#           'unharden': 1,
#           'cunning': 2,
#           'filch': 1,
#           'heart': 21,
#           'obedience': 1,
#           'which': 38,
#           'due': 3,
#           'me': 176,
#           'stubborn': 1,
#           'harshness': 1,
#           'so': 115,
#           'here': 68,
#           'before': 10,
#           'your': 123,
#           'grace': 11,
#           'beg': 6,
#           'ancient': 2,
#           'privilege': 3,
#           'as': 117,
#           'mine': 23,
#           'may': 31,
#           'dispose': 1,
#           'either': 7,
#           'gentleman': 6,
#           'death': 14,
#           'according': 3,
#           'law': 6,
#           'immediately': 2,
#           'provided': 1,
#           'that': 186,
#           'case': 3,
#           'say': 26,
#           'you': 274,
#           'advised': 1,
#           'maid': 8,
#           'should': 35,
#           'god': 7,
#           'one': 43,
#           'composed': 1,
#           'beauties': 1,
#           'yea': 4,
#           'whom': 5,
#           'are': 67,
#           'form': 2,
#           'wax': 1,
#           'him': 51,
#           'imprinted': 1,
#           'within': 10,
#           'his': 89,
#           'power': 9,
#           'leave': 15,
#           'figure': 2,
#           'disfigure': 2,
#           'worthy': 1,
#           'himself': 7,
#           'he': 91,
#           'kind': 5,
#           'wanting': 1,
#           'must': 44,
#           'held': 1,
#           'worthier': 2,
#           'would': 40,
#           'look': 33,
#           'eyes': 41,
#           'rather': 6,
#           'judgment': 2,
#           'do': 106,
#           'entreat': 5,
#           'pardon': 3,
#           'know': 24,
#           'am': 56,
#           'made': 14,
#           'bold': 2,
#           'nor': 20,
#           'concern': 1,
#           'modesty': 5,
#           'such': 24,
#           'presence': 4,
#           'plead': 1,
#           'thoughts': 2,
#           'beseech': 3,
#           'worst': 2,
#           'befall': 2,
#           'if': 65,
#           'refuse': 1,
#           'die': 12,
#           'abjure': 1,
#           'ever': 15,
#           'society': 1,
#           'men': 13,
#           'therefore': 19,
#           'question': 2,
#           'examine': 1,
#           'well': 31,
#           'blood': 8,
#           'whether': 3,
#           'yield': 3,
#           'choice': 6,
#           'can': 32,
#           'endure': 1,
#           'livery': 1,
#           'nun': 1,
#           'aye': 3,
#           'shady': 1,
#           'cloister': 1,
#           'mew': 1,
#           'live': 5,
#           'barren': 2,
#           'sister': 1,
#           'all': 91,
#           'life': 14,
#           'chanting': 1,
#           'faint': 3,
#           'hymns': 1,
#           'cold': 3,
#           'fruitless': 2,
#           'thrice': 2,
#           'blessed': 5,
#           'they': 34,
#           'undergo': 1,
#           'maiden': 5,
#           'pilgrimage': 1,
#           'earthlier': 1,
#           'rose': 5,
#           'distill': 1,
#           'than': 33,
#           'virgin': 3,
#           'thorn': 4,
#           'grows': 3,
#           'lives': 1,
#           'dies': 3,
#           'single': 4,
#           'blessedness': 1,
#           'grow': 6,
#           'ere': 13,
#           'patent': 1,
#           'unto': 10,
#           'lordship': 1,
#           'whose': 8,
#           'unwished': 1,
#           'yoke': 2,
#           'soul': 8,
#           'consents': 1,
#           'give': 20,
#           'sovereignty': 1,
#           'take': 24,
#           'pause': 1,
#           'nest': 1,
#           '--': 11,
#           'sealing': 1,
#           'day': 24,
#           'betwixt': 1,
#           'everlasting': 1,
#           'bond': 3,
#           'fellowship': 1,
#           'upon': 29,
#           'prepare': 1,
#           'disobedience': 1,
#           'else': 10,
#           'diana': 1,
#           'altar': 1,
#           'protest': 1,
#           'austerity': 1,
#           'relent': 1,
#           'sweet': 47,
#           'crazed': 1,
#           'title': 1,
#           'certain': 5,
#           'right': 7,
#           'have': 99,
#           'let': 39,
#           'scornful': 1,
#           'true': 27,
#           'render': 2,
#           'estate': 1,
#           'derived': 1,
#           'possess': 1,
#           'more': 50,
#           'fortunes': 1,
#           'every': 19,
#           'way': 9,
#           'fairly': 1,
#           'rank': 1,
#           'vantage': 1,
#           "';": 1,
#           'these': 31,
#           'boasts': 1,
#           'beloved': 1,
#           'beauteous': 2,
#           'why': 22,
#           'prosecute': 1,
#           'll': 32,
#           'avouch': 1,
#           'head': 12,
#           'nedar': 2,
#           'lady': 11,
#           'dotes': 3,
#           'devoutly': 1,
#           'idolatry': 1,
#           'spotted': 2,
#           'inconstant': 1,
#           'confess': 3,
#           'heard': 10,
#           'much': 11,
#           'thought': 5,
#           'spoke': 2,
#           'thereof': 1,
#           'being': 9,
#           'over': 8,
#           'self': 1,
#           'affairs': 1,
#           'mind': 4,
#           'did': 37,
#           'lose': 4,
#           'some': 37,
#           'private': 1,
#           'schooling': 1,
#           'both': 12,
#           'arm': 2,
#           'yourself': 3,
#           'fit': 3,
#           'fancies': 1,
#           'yields': 1,
#           'no': 85,
#           'means': 2,
#           'we': 80,
#           'extenuate': 1,
#           'vow': 3,
#           'cheer': 4,
#           'along': 1,
#           'employ': 2,
#           'business': 2,
#           'confer': 1,
#           'something': 4,
#           'nearly': 1,
#           'concerns': 1,
#           'yourselves': 3,
#           'duty': 5,
#           'desire': 9,
#           'follow': 21,
#           'exeunt': 17,
#           'cheek': 2,
#           'chance': 2,
#           'roses': 3,
#           'there': 37,
#           'fade': 1,
#           'fast': 3,
#           'belike': 1,
#           'want': 2,
#           'rain': 1,
#           'could': 13,
#           'beteem': 1,
#           'them': 27,
#           'from': 58,
#           'tempest': 1,
#           'ay': 11,
#           'aught': 2,
#           'read': 3,
#           'hear': 20,
#           'tale': 2,
#           'history': 1,
#           'course': 1,
#           'never': 36,
#           'run': 8,
#           'smooth': 2,
#           'was': 30,
#           'different': 1,
#           ',--': 22,
#           'cross': 4,
#           'too': 19,
#           'high': 4,
#           'enthrall': 1,
#           'low': 6,
#           'misgraffed': 1,
#           'respect': 4,
#           'years': 1,
#           'spite': 5,
#           'engaged': 1,
#           'stood': 2,
#           'friends': 9,
#           'hell': 5,
#           'choose': 1,
#           'were': 17,
#           'sympathy': 1,
#           'war': 2,
#           'sickness': 3,
#           'lay': 3,
#           'siege': 1,
#           'making': 2,
#           'momentany': 1,
#           'sound': 7,
#           'swift': 2,
#           'shadow': 1,
#           'short': 2,
#           'any': 8,
#           'brief': 6,
#           'lightning': 1,
#           'collied': 1,
#           'spleen': 1,
#           'unfolds': 1,
#           'earth': 6,
#           "!'": 2,
#           'jaws': 1,
#           'darkness': 2,
#           'devour': 1,
#           'quick': 3,
#           'bright': 4,
#           'things': 16,
#           'confusion': 2,
#           'lovers': 17,
#           'been': 4,
#           'stands': 2,
#           'an': 35,
#           'edict': 1,
#           'destiny': 1,
#           'us': 24,
#           'teach': 3,
#           'trial': 1,
#           'patience': 5,
#           'because': 7,
#           'customary': 1,
#           'dreams': 2,
#           'sighs': 2,
#           'wishes': 1,
#           'tears': 8,
#           'poor': 9,
#           'fancy': 5,
#           'followers': 1,
#           'persuasion': 1,
#           'widow': 1,
#           'aunt': 2,
#           'great': 8,
#           'house': 11,
#           'remote': 1,
#           'seven': 1,
#           'leagues': 1,
#           'respects': 1,
#           'only': 5,
#           'son': 3,
#           'gentle': 16,
#           'place': 12,
#           'sharp': 1,
#           'cannot': 13,
#           'pursue': 4,
#           'lovest': 1,
#           'steal': 4,
#           'morrow': 8,
#           'league': 3,
#           'without': 5,
#           'town': 4,
#           'where': 30,
#           'meet': 17,
#           'once': 9,
#           'observance': 1,
#           'morn': 2,
#           'stay': 14,
#           'swear': 6,
#           'cupid': 8,
#           'strongest': 1,
#           'best': 9,
#           'arrow': 2,
#           'golden': 2,
#           'simplicity': 2,
#           'venus': 3,
#           'doves': 1,
#           'knitteth': 1,
#           'souls': 3,
#           'prospers': 1,
#           'loves': 9,
#           'fire': 5,
#           'burn': 2,
#           'carthage': 1,
#           'when': 59,
#           'false': 4,
#           'troyan': 1,
#           'under': 2,
#           'sail': 2,
#           'seen': 6,
#           'vows': 5,
#           'broke': 2,
#           'number': 2,
#           'women': 1,
#           'same': 10,
#           'appointed': 1,
#           'truly': 6,
#           'keep': 9,
#           'promise': 4,
#           'comes': 16,
#           'speed': 3,
#           'whither': 2,
#           'call': 11,
#           'again': 14,
#           'unsay': 1,
#           'lode': 1,
#           'stars': 3,
#           'tongue': 15,
#           'air': 3,
#           'tuneable': 2,
#           'lark': 3,
#           'shepherd': 1,
#           'ear': 8,
#           'wheat': 1,
#           'green': 9,
#           'hawthorn': 2,
#           'buds': 4,
#           'appear': 5,
#           'catching': 1,
#           'favour': 1,
#           'yours': 4,
#           'catch': 5,
#           'eye': 21,
#           'melody': 3,
#           'world': 6,
#           'bated': 1,
#           'rest': 13,
#           'translated': 3,
#           'art': 16,
#           'sway': 2,
#           'motion': 1,
#           'frown': 1,
#           'yet': 26,
#           'still': 8,
#           'frowns': 1,
#           'smiles': 1,
#           'skill': 3,
#           'curses': 1,
#           'gives': 2,
#           'prayers': 2,
#           'affection': 2,
#           'move': 3,
#           'hate': 9,
#           'follows': 1,
#           'hateth': 1,
#           'folly': 2,
#           'fault': 3,
#           'none': 8,
#           'beauty': 2,
#           'comfort': 2,
#           'see': 41,
#           'face': 9,
#           'myself': 5,
#           'fly': 6,
#           'seem': 8,
#           'paradise': 1,
#           'graces': 1,
#           'dwell': 1,
#           'helen': 8,
#           'minds': 4,
#           'unfold': 1,
#           'phoebe': 1,
#           'doth': 31,
#           'visage': 2,
#           'watery': 3,
#           'glass': 2,
#           'decking': 1,
#           'liquid': 1,
#           'pearl': 2,
#           'bladed': 1,
#           'grass': 2,
#           'flights': 1,
#           'conceal': 1,
#           'through': 27,
#           'gates': 2,
#           'devised': 1,
#           'often': 5,
#           'primrose': 1,
#           'beds': 2,
#           'wont': 4,
#           'lie': 7,
#           'emptying': 1,
#           'bosoms': 4,
#           'counsel': 3,
#           'thence': 2,
#           'seek': 7,
#           'stranger': 2,
#           'companies': 1,
#           'farewell': 3,
#           'playfellow': 1,
#           'pray': 14,
#           'luck': 3,
#           'grant': 2,
#           'word': 9,
#           'starve': 1,
#           'sight': 10,
#           'food': 2,
#           'till': 13,
#           'deep': 3,
#           'midnight': 3,
#           'adieu': 5,
#           'dote': 5,
#           'er': 16,
#           'thinks': 1,
#           'errs': 1,
#           'doting': 1,
#           'admiring': 1,
#           'qualities': 1,
#           'base': 1,
#           'vile': 8,
#           'folding': 1,
#           'quantity': 1,
#           'transpose': 1,
#           'dignity': 1,
#           'looks': 4,
#           'wing': 1,
#           'painted': 3,
#           'blind': 2,
#           'judgement': 1,
#           'taste': 3,
#           'wings': 4,
#           'unheedy': 1,
#           'haste': 3,
#           'said': 4,
#           'oft': 2,
#           'beguiled': 2,
#           'waggish': 1,
#           'boys': 1,
#           'game': 2,
#           'forswear': 1,
#           'boy': 9,
#           'perjured': 1,
#           'eyne': 4,
#           'hail': 6,
#           'down': 16,
#           'oaths': 2,
#           'heat': 1,
#           'felt': 1,
#           'dissolved': 1,
#           'showers': 1,
#           'melt': 1,
#           'tell': 16,
#           'flight': 3,
#           'intelligence': 1,
#           'dear': 15,
#           'expense': 1,
#           'herein': 1,
#           'mean': 4,
#           'enrich': 1,
#           'pain': 2,
#           'thither': 1,
#           'back': 10,
#           'ii': 5,
#           'company': 9,
#           'generally': 1,
#           'scrip': 1,
#           'scroll': 2,
#           'name': 14,
#           'play': 35,
#           'interlude': 2,
#           'duchess': 2,
#           'wedding': 2,
#           'first': 9,
#           'peter': 8,
#           'treats': 1,
#           'names': 1,
#           'actors': 4,
#           'point': 2,
#           'most': 21,
#           'lamentable': 1,
#           'comedy': 3,
#           'cruel': 3,
#           'pyramus': 57,
#           'thisby': 29,
#           'very': 11,
#           'piece': 1,
#           'work': 4,
#           'assure': 1,
#           'merry': 4,
#           'masters': 7,
#           'spread': 1,
#           'answer': 6,
#           'nick': 2,
#           'ready': 6,
#           'part': 16,
#           'proceed': 3,
#           'set': 8,
#           'lover': 10,
#           'tyrant': 3,
#           'kills': 2,
#           'gallant': 2,
#           'ask': 3,
#           'performing': 1,
#           'audience': 1,
#           'storms': 1,
#           'condole': 1,
#           'measure': 3,
#           'chief': 1,
#           'humour': 1,
#           'ercles': 2,
#           'rarely': 1,
#           'tear': 2,
#           'cat': 3,
#           'make': 37,
#           'split': 1,
#           'raging': 1,
#           'rocks': 1,
#           'shivering': 1,
#           'shocks': 1,
#           'break': 7,
#           'locks': 1,
#           'prison': 1,
#           'phibbus': 1,
#           'car': 1,
#           'shine': 6,
#           'far': 6,
#           'mar': 1,
#           'foolish': 3,
#           'fates': 3,
#           'lofty': 1,
#           'players': 2,
#           'vein': 3,
#           'condoling': 1,
#           'francis': 1,
#           'wandering': 4,
#           'knight': 4,
#           'nay': 9,
#           'faith': 6,
#           'woman': 5,
#           'beard': 7,
#           'coming': 4,
#           'mask': 1,
#           'speak': 28,
#           'small': 4,
#           'hide': 4,
#           'monstrous': 3,
#           'little': 11,
#           'thisne': 2,
#           ";'": 2,
#           'ah': 2,
#           'mother': 5,
#           'tom': 1,
#           'lion': 35,
#           'hope': 3,
#           'fitted': 2,
#           'written': 4,
#           'study': 1,
#           'extempore': 1,
#           'nothing': 13,
#           'roaring': 2,
#           'roar': 8,
#           ".'": 7,
#           'terribly': 1,
#           'fright': 3,
#           'ladies': 10,
#           'shriek': 1,
#           'enough': 11,
#           'hang': 6,
#           'wits': 1,
#           'discretion': 6,
#           'aggravate': 1,
#           'gently': 2,
#           'sucking': 1,
#           'dove': 4,
#           'twere': 2,
#           'nightingale': 1,
#           'faced': 2,
#           'proper': 1,
#           'summer': 5,
#           'lovely': 7,
#           'needs': 4,
#           'undertake': 1,
#           'discharge': 2,
#           'straw': 1,
#           'colour': 3,
#           'orange': 2,
#           'tawny': 3,
#           'purple': 4,
#           'grain': 1,
#           'french': 2,
#           'crown': 2,
#           'perfect': 2,
#           'yellow': 4,
#           'crowns': 2,
#           'bare': 1,
#           'parts': 3,
#           'request': 2,
#           'con': 1,
#           'mile': 1,
#           'rehearse': 5,
#           'city': 2,
#           'dogged': 1,
#           'devices': 1,
#           'known': 3,
#           'meantime': 1,
#           'draw': 5,
#           'bill': 2,
#           'properties': 1,
#           'wants': 1,
#           'fail': 2,
#           'obscenely': 1,
#           'courageously': 1,
#           'pains': 1,
#           'oak': 1,
#           'hold': 8,
#           'cut': 4,
#           'strings': 2,
#           'opposite': 1,
#           'sides': 2,
#           'fairy': 28,
#           'wander': 2,
#           'hill': 2,
#           'dale': 2,
#           'thorough': 5,
#           'bush': 8,
#           'brier': 4,
#           'park': 1,
#           'flood': 2,
#           'everywhere': 1,
#           'swifter': 4,
#           'sphere': 2,
#           'serve': 3,
#           'dew': 6,
#           'orbs': 1,
#           'cowslips': 1,
#           'tall': 3,
#           'pensioners': 1,
#           'gold': 2,
#           'coats': 3,
#           'spots': 1,
#           'those': 7,
#           'rubies': 1,
#           'favours': 2,
#           'freckles': 1,
#           'savours': 3,
#           'dewdrops': 1,
#           'cowslip': 2,
#           'lob': 1,
#           'spirits': 4,
#           'gone': 16,
#           'elves': 4,
#           'anon': 5,
#           'heed': 1,
#           'passing': 1,
#           'fell': 6,
#           'wrath': 1,
#           'attendant': 2,
#           'indian': 3,
#           'had': 20,
#           'changeling': 3,
#           'jealous': 2,
#           'train': 8,
#           'trace': 1,
#           'forests': 1,
#           'wild': 5,
#           'perforce': 4,
#           'withholds': 1,
#           'loved': 5,
#           'flowers': 5,
#           'makes': 5,
#           'joy': 8,
#           'grove': 5,
#           'fountain': 2,
#           'clear': 2,
#           'spangled': 1,
#           'starlight': 2,
#           'sheen': 1,
#           'square': 1,
#           'fear': 18,
#           'creep': 3,
#           'into': 9,
#           'acorn': 2,
#           'cups': 1,
#           'mistake': 2,
#           'shape': 3,
#           'quite': 4,
#           'shrewd': 2,
#           'knavish': 2,
#           'sprite': 3,
#           'frights': 1,
#           'maidens': 2,
#           'villagery': 1,
#           'skim': 1,
#           'milk': 3,
#           'sometimes': 2,
#           'labour': 2,
#           'quern': 1,
#           'bootless': 2,
#           'breathless': 1,
#           'housewife': 1,
#           'churn': 1,
#           'sometime': 10,
#           'drink': 1,
#           'bear': 11,
#           'barm': 1,
#           'mislead': 1,
#           'wanderers': 1,
#           'laughing': 1,
#           'harm': 6,
#           'hobgoblin': 1,
#           'st': 11,
#           'aright': 1,
#           'wanderer': 2,
#           'jest': 4,
#           'smile': 1,
#           'fat': 1,
#           'bean': 1,
#           ...})

# %% [markdown]
# **Q2. Finding most frequently occuring words from the file dream.xml.**

# %%
Dictionary=dict(fdist)

# %%
 from collections import Counter
 dict(Counter(Dictionary).most_common(5))
# Out:
# {'and': 574, 'i': 470, 'the': 563, 'to': 340, 'you': 274}

# %% [markdown]
# **Q3.Import Wordnet Corpus from the available nltk corpus list and find out the sysnset of the word Bank.Also find the definition and example of first sysnset in the list.**

# %%
nltk.download('wordnet')
from nltk.corpus import wordnet 
syns=wordnet.synsets("Bank")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
print("Definition of the word Bank:")
print(syns[0].definition())
print("\nExamples of the word Bank:")
print(syns[0].examples())
# Out:
# Definition of the word Bank:
# sloping land (especially the slope beside a body of water)
#
# Examples of the word Bank:
# ['they pulled the canoe up on the bank', 'he sat on the bank of the river and watched the currents']
